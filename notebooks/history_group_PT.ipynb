# %% [markdown]
# # Descobrindo o Histórico de Produção do Grupo de Pesquisadores

# %% [markdown]
# A biblioteca LattesLab pode ser usada para recuperar os resultados de produtividade de um grupo de pesquisadores. Uma vez que os currículos Lattes desses pesquisadores são baixados e armazenados em uma pasta, a análise pode ser realizada, de acordo com as etapas deste Notebook Jupyter.
#
# Primeiro de tudo, a biblioteca LattesLab deve ser importada.

# %%
import LattesLab as ll

# %% [markdown]
# Nas seguintes células, as variáveis são definidas:
# - "folder" é uma string com a pasta que contém os arquivos Lattes CV do grupo de pesquisadores
# - "params" é uma lista de strings. Cada string de "params" é um parâmetro a ser recuperado do arquivo CV do Lattes. Deve ser um subconjunto de 'papers', 'works', 'orientations', 'capítulos' e 'livros'
# - "nyears" é um inteiro contendo o número de anos, do ano atual para trás, a ser recuperado dos currículos Lattes.

# %%
#folder = 'C:\\Users\\thiag\\Desktop\\work\\'
folder = "D:\\thiag\\Documents\\INPE\\Research\\Datasets\\PIBIC"
params = ['papers', 'works', 'orientations', 'chapters', 'books']
nyears = 20

# %% [markdown]
# Finalmente, o histórico pode ser descoberto com a função do LattesLab get_history_file_n.

# %%
myhist = ll.get_history_file_n(folder, params, nyears)

# %% [markdown]
# [Abrir menu principal](start.ipynb)
