# %% [markdown]
# # Top Words in Publication's Titles

# %% [markdown]
# The code in this notebook extracts the data from the Lattes CVs in a list of folders and creates wordclouds of the most frequent terms found in each researcher's publications titles.
#
# Explanations for the code will follow each cell. The cell below is reserved for definitions and load of Python packages.

# %%
import LattesLab as ll

# %% [markdown]
# The variable "folderlist" contains the list of folder paths where the Lattes CV collection is found.

# %%
folderlist = ["C:\\Users\\thiag\\Desktop\\work"]

# %% [markdown]
# The function get_pub_dataframe_from_folders creates a dataframe from the Lattes CVs on the folders. The second parameter (either True or False) defines if this dataframe will be saved to a csv file for later use.

# %%
pubframe = ll.get_pub_dataframe_from_folders(folderlist, False)

# %% [markdown]
# To see what the dataframe looks like, let's take a look at the first lines of its data.

# %%
pubframe.head()
# Out:
#                      Nome          lattesId  type  \
# 0  Eduardo Martins Guerra  3413978291577451  work
# 1  Eduardo Martins Guerra  3413978291577451  work
# 2  Eduardo Martins Guerra  3413978291577451  work
# 3  Eduardo Martins Guerra  3413978291577451  work
# 4  Eduardo Martins Guerra  3413978291577451  work
#
#                                                title  year      idiom
# 0  RBAC COM CONTEXTOS: MODELO DE CONTROLE DE ACES...  2004  Português
# 1                       Refactoring Test Code Safely  2007     Inglês
# 2  Modelo de Controle de Acesso para uma Arquitet...  2007  Português
# 3  Access Control Solution for Command and Contro...  2008  Português
# 4                  A Metadata-Based Components Model  2008  Português

# %% [markdown]
# The function get_wordclouds_from_pub_frame creates wordclouds with the most frequent terms found on the titles of each researcher's publications.
#
# - a is the list of the researchers names
# - b is the list of the list of titles published by each researcher
# - c is the list of the most frequent terms found in the titles of the researcher's publications.
#
# The first parameter of the function is the dataframe retrieved from the get_pub_dataframe_from_folders function. The second parameter (either True or False) defines if this dataframe will be saved to a csv file for later use.

# %%
[a, b, c] = ll.get_wordclouds_from_pub_frame(pubframe, False)

# %% [markdown]
# [Open Main Menu](start_EN.ipynb)
