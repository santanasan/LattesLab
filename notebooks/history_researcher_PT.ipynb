# %% [markdown]
# # Encontrando o Histórico de Produção de um Pesquisador

# %% [markdown]
# Um dos resultados mais diretos a serem alcançados com a biblioteca LattesLab é determinar a história da produção de um determinado pesquisador. Este caderno mostra como isso pode ser feito.
#
# Primeiro de tudo, a biblioteca LattesLab deve ser importada.

# %%
import LattesLab as ll

# %% [markdown]
# Nas seguintes células, as variáveis são definidas:
# - "folder" contém a pasta que contém o arquivo CV do Lattes
# - "file" contém o nome do arquivo CV do Lattes
# - "params" é uma lista de strings. Cada string de "params" é um parâmetro a ser recuperado do arquivo CV do Lattes. Deve ser um subconjunto de 'papers' (artigos), 'works' (trabalhos em congressos), 'orientations' (orientações de mestrado e doutorado), 'chapters' (capítulos) e 'books' (livros)
# - "nyears" é um inteiro contendo o número de anos, do ano atual para trás, a ser recuperado dos Currículos Lattes.

# %%
folder = 'C:\\Users\\thiag\\Desktop\\work\\'
file = 'K4703212T1.zip'
params = ['papers', 'works', 'orientations', 'chapters', 'books']
nyears = 20

# %% [markdown]
# Finalmente, o histórico pode ser descoberto no LattesLab e no arquivo CV do Lattes.

# %%
myhist = ll.get_history_file_1(folder, file, params, nyears)

# %% [markdown]
# [Abrir menu principal](start.ipynb)
