# %% [markdown]
# # Rate of Degrees per Year

# %% [markdown]
# The code in this notebook extracts the data from the Lattes CVs in a folder and creates histograms of the distribution of titles per year.
#
# Explanations for the code will follow each cell. The cell below is reserved for definitions and load of Python packages.

# %%
import LattesLab as ll

# %% [markdown]
# The variable "folderlist" contains the list of folder paths where the Lattes CV collection is found.

# %%
folderlist = ['D:\\thiag\\Documents\\INPE\\Research\\Datasets\\PIBIC']

# %% [markdown]
# The function get_dataframe_from_folder creates a dataframe from those Lattes CVs on the folders. The second parameter (either True or False) defines if this dataframe will be saved to a csv file for later use.

# %%
lattesframe = ll.get_dataframe_from_folders(folderlist, True)

# %% [markdown]
# Before any analysis, let's say we want to filter the Lattes CVs that were updated from 1990 to today. Then we could add the filter below:

# %%
refdate1 = '01011990'
refdate2 = 'today'

lattesframe = ll.filter_by_date(lattesframe, refdate1, refdate2)

# %% [markdown]
# Finally, the histograms of the distribution of degrees per year can be generated, for that Lattes CV collection.

# %%
ll.degree_rate_year(lattesframe, 'G')
ll.degree_rate_year(lattesframe, 'M')
ll.degree_rate_year(lattesframe, 'D')
ll.degree_rate_year(lattesframe, 'PD')

# %% [markdown]
# [Open Main Menu](start_EN.ipynb)
