# %% [markdown]
# # CRIE GRÁFOS DE COLEÇÕES DE CURRÍCULOS LATTES  NUMA PASTA

# %% [markdown]
# O código deste notebook extrai dos arquivos de Currículos Lattes os pesquisadores que foram coautores do dono de cada Currículo Lattes em publicações científicas.
#
# Explicações para o código seguirão cada célula. A célula abaixo é reservada para definições e carregamento de pacotes Python.

# %%
import LattesLab as ll

# %% [markdown]
# A variável "folder" contém o nome da pasta onde a coleção de Currículos Lattes é encontrada.

# %%
#folder = "C:\\Users\\thiag\\Desktop\\work\\"
folder = "D:\\thiag\\Documents\\INPE\\Research\\Datasets\\PIBIC"

# %% [markdown]
# O código na célula a seguir lê cada Currículo Lattes na pasta e cria uma rede de nós. Cada nó representa um pesquisador e cada aresta entre os nós significa que os pesquisadores desses dois nós publicaram juntos.
#
# É esperado que os pesquisadores cujos Currículos Lattes sejam encontrados na pasta contenham um número maior de arestas.
#
# A função classifica os proprietários dos Currículos Lattes encontrados na pasta como parte de um grupo - com o rótulo "interno". Outros pesquisadores encontrados nos Currículos Lattes são classificados em outro grupo - com o rótulo "externo".
#
# O grafo de rede é plotado em seguida. Os nós azuis são os pesquisadores do grupo interno e os nós vermelhos são os do grupo externo. O layout escolhido para representar o grupo é chamado de layout de shell. É possível organizar o grupo interno interno e externo do grupo, para ter uma noção das arestas entre os grupos.
#
# A função também salva a figura e a correlação entre os inteiros associados a cada nó e o respectivo nome do pesquisador.
#
# Abaixo do nó é mostrado um ranking das principais parcerias de publicações encontradas na análise.

# %%
[graph, graphframe] = ll.get_graph_from_folder(folder)
# Out:
# C:\Users\thiag\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
# Anderson de Oliveira Lobo and Fernanda Roberta Marciano have worked together 143 times.
# Carlos Roberto Braga and Alisson Dal Lago have worked together 81 times.
# Fernanda Roberta Marciano and Vladimir Jesus Trava Airoldi have worked together 73 times.
# Nelson Jorge Schuch and Carlos Roberto Braga have worked together 69 times.
# Laysa Cristina Araújo Resende and Clezio M. De Nardin have worked together 65 times.
# Fernanda Roberta Marciano and Evaldo José Corat have worked together 59 times.
# Nelson Jorge Schuch and Juliano Moro have worked together 58 times.
# Juliano Moro and Clezio Marcos De Nardin have worked together 54 times.
# Nelson Jorge Schuch and Jairo Francisco Savian have worked together 53 times.
# Leandro Zanella de Souza Campos and Marcelo Magalhães Fares Saba have worked together 53 times.
# ...

# %% [markdown]
# A célula abaixo mostra a matriz de dados (dataframe) que foi gerada da análise dos Curriculos Lattes. São listados:
# - O nome do pesquisador;
# - A quantidade de co-autores deste pesquisador em firstconnections;
# - A quantidade de co-autores dos co-autores deste pesquisador em secondconnections;
# - Uma razão entre ambas as grandezas (firstconnections dividido por secondconnections) em ratio.

# %%
graphframe
# Out:
#                                             name  firstconnections  \
# 0              Jefferson Alves Nogueira da Silva                 0
# 1             Regiane Donizeti de Souza Martinez                 0
# 2                  Henrique de oliveira euclides                 6
# 3              Priscila Mayumi Pereira Yaguinuma                 0
# 4                        Ádanna de Souza Andrade                22
# 5                    Heber Albuquerque Gonçalves                 0
# 6                   Tiago Nogueira de Sá Miranda                 5
# 7                               Luiz Carlos Rosa                 0
# 8                         Vinícius Bigogno Costa                 0
# 9                           Thales Koba de Moura                 6
# 10                          Amanda Rosa da Silva                 1
# 11               Rafael Guimarães Pequeno França                 0
# 12                          Ana Luiza Dors Wilke                 0
# ...

# %% [markdown]
# [Abrir menu principal](start.ipynb)
