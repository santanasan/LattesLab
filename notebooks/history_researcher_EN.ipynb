# %% [markdown]
# # Finding the Production History of one Researcher

# %% [markdown]
# One of the most straightforward results to be achieved with the LattesLab library is to find the history of production of a given researcher. This notebook shows how it can be done.
#
# First of all, the LattesLab library must be imported.

# %%
import LattesLab as ll

# %% [markdown]
# In the following cells, the variables are defined:
# - "folder" is a string with the folder that holds the Lattes CV file
# - "file" is a string with the name of the Lattes CV file
# - "params" is a list of strings. Each string of "params" is a parameter to be retrieved from the Lattes CV file. Must be a subset of 'papers', 'works', 'orientations', 'chapters' and 'books'
# - "nyears" is an integer containing the number of years, from the current year backwards, to be retrieved from the Lattes CVs.

# %%
folder = 'C:\\Users\\thiag\\Desktop\\work\\'
file = 'K4703212T1.zip'
params = ['papers', 'works', 'orientations', 'chapters', 'books']
nyears = 20

# %% [markdown]
# Finally, the history can be discovered from LattesLab and the Lattes CV file.

# %%
myhist = ll.get_history_file_1(folder, file, params, nyears)

# %% [markdown]
# [Open Main Menu](start_EN.ipynb)
